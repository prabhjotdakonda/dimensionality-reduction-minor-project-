# %% [markdown]
# <a href="https://colab.research.google.com/github/prabhjotdakonda/dimensionality-reduction-minor-project-/blob/main/wine_quality_dataset(minor_project).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
